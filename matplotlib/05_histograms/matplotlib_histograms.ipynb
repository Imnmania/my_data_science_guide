# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.hist(blood_sugar) ## default bin size 10
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar, bins=10, rwidth=0.95)
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
## mention the range splicitly

plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, color='g')
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, color='g', histtype='step')
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  [<matplotlib.patches.Polygon at 0x7f4f11bc3370>])

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel('Sugar Range')
plt.ylabel('Number of Patients')
plt.title('Blood Sugar Analysis')

plt.hist([blood_sugar_men, blood_sugar_women], bins=[80,100,125,150], color=['green','blue'], 
         rwidth=0.95, label=['men','women'])
plt.legend()
